# %% [markdown]
# <a href="https://colab.research.google.com/github/harenlin/Sentiment-Analysis-With-Tensorflow/blob/main/Sentiment_Analysis_with_RNN_%26_CNN_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis with RNN

# %% [markdown]
# import package

# %%
import os
import time
import pprint
import logging
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import tensorflow as tf
from collections import Counter
from pathlib import Path
from tqdm import tqdm
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# load in dataset

# %%
# file path to training data
train_path = '/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt'
# calculate how many non-repeating words in corpus
counter = Counter() 
with open(train_path, encoding='utf-8') as f:
    for line in f:
        line = line.rstrip()
        label, words = line.split('\t')
        words = words.split(' ')
        counter.update(words)
# filt the words, only reserve for the word which occurs over 10 times
words = ['<pad>'] + [w for w, freq in counter.most_common() if freq >= 10]
print('Vocab Size:', len(words)) # Vocab Size: 20598
# save vocab.txt
Path('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab').mkdir(exist_ok=True)
with open('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.txt', 'w',encoding='utf-8') as f:
    for w in words:
        f.write(w+'\n')
# create word2idx and idx2word
word2idx = {}
with open('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.txt', encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i
        
idx2word = dict(zip(word2idx.values(), word2idx.keys()))
# Out:
# Vocab Size: 20598

# %% [markdown]
# Embedding Layer
# -> 可以抓取別人已經Pre-trained好的模型來用(e.g. https://nlp.stanford.edu/projects/glove/)
# ，也可以用自己手上的資料集來訓練

# %%
# we choose to use the simple glove pre-trained model as our embedding representation
# if the token is not exist in our vocab.txt -> make it as [UNK] = unknown
# declare 2d-array for representing embedding of each word in vocab.txt
embedding = np.zeros((len(word2idx)+1, 50))

with open('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/glove.6B.50d.txt', encoding='utf-8') as f:
    count = 0
    for i, line in enumerate(f):
        line = line.rstrip()
        sp = line.split(' ')
        word, representation = sp[0], sp[1:]
        if word in word2idx:
            embedding[word2idx[word]] = np.asarray(representation, dtype='float32') 
            count += 1

print("[%d / %d] words have found pre-trained values" % (count, len(word2idx)))
np.save('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.npy', embedding)
print('Saved /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.npy')
# Out:
# [19676 / 20598] words have found pre-trained values
# Saved /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.npy

# %% [markdown]
# Establish Training Data
# -> we need to pay attention that all the input data have to be with same size

# %%
# tf.data.Dataset.from_tensor_slices(tensor)
# tf.data.Dataset.from_generator(data_generator,output_data_type,output_data_shape)

# %%
def data_generator(file_path, parameters):
    with open(file_path, encoding='utf-8') as f:
        print('Reading Data from ', file_path)
        for line in f:
            line = line.rstrip()
            label, text = line.split('\t')
            text = text.split(' ')
            x_data = [parameters['word2idx'].get(word, len(word2idx)) for word in text]
            if len(x_data) >= parameters['max_seq_len']: x_data = x_data[:parameters['max_seq_len']]
            else: x_data += [0] * (parameters['max_seq_len'] - len(x_data)) # padding
                  # why pad 0? since word2idx['<pad>'] = 0
            y_label = int(label)
            # print( np.array(x_data).shape ) # (1000,) = (parameters['max_seq_len'],)
            yield x_data, y_label # not return x, y -> since generator

# %%
# next(data_generator(parameters['train_path'], parameters))

# %%
# remember to add "lambda" to avoid TypeError: `generator` must be callable.
def dataset(isTraining, parameters):
    shapes = (parameters['max_seq_len'], ())
    types = (tf.int32, tf.int32)
    if isTraining:
        dataSet = tf.data.Dataset.from_generator(
            lambda: data_generator(parameters['train_path'], parameters),
            output_types=types, output_shapes=shapes, )
        dataSet = dataSet.shuffle(parameters['num_samples'])
        dataSet = dataSet.batch(parameters['batch_size'])
        dataSet = dataSet.prefetch(tf.data.experimental.AUTOTUNE)
    else:
        dataSet = tf.data.Dataset.from_generator(
            lambda: data_generator(parameters['test_path'], parameters),
            output_types=types, output_shapes=shapes, )
        dataSet = dataSet.batch(parameters['batch_size'])
        dataSet = dataSet.prefetch(tf.data.experimental.AUTOTUNE)
    return dataSet

# %%
parameters = {
    'vocab_path': '/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.txt',
    'train_path': '/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt',
    'test_path': '/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/test.txt',
    'num_samples': 25000,
    'num_labels': 2,
    'batch_size': 128,
    'max_seq_len': 1000,
    'rnn_units': 200,
    'dropout_rate': 0.2,
    'clip_norm': 10.,
    'num_patience': 5,
    'learning_rate': 1e-3,
}

word2idx = {}
with open(parameters['vocab_path'], encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i
parameters['word2idx'] = word2idx
parameters['vocab_size'] = len(word2idx) + 1

# %% [markdown]
# Define Network

# %%
class Model(tf.keras.Model):
    def __init__(self, parameters):
        super().__init__()
        self.embedding = tf.Variable(np.load('/content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/vocab/word.npy'),
                                     dtype=tf.float32, name='pretrained_embedding', trainable=False,)
        self.dropout = tf.keras.layers.Dropout(parameters['dropout_rate'])
        self.rnn1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(parameters['rnn_units'], return_sequences=True))
        self.rnn2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(parameters['rnn_units'], return_sequences=True))
        self.rnn3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(parameters['rnn_units'], return_sequences=False))
        self.fc = tf.keras.layers.Dense(2 * parameters['rnn_units'], tf.nn.elu)
        self.out_linear = tf.keras.layers.Dense(2)
  
    def call(self, inputs, training=False):
        if inputs.dtype != tf.int32: inputs = tf.cast(inputs, tf.int32)
        x = tf.nn.embedding_lookup(self.embedding, inputs)
        x = self.dropout(x, training=training)
        x = self.rnn1(x)
        x = self.dropout(x, training=training)
        x = self.rnn2(x)
        x = self.dropout(x, training=training)
        x = self.rnn3(x)
        x = self.dropout(x, training=training)
        x = self.fc(x)
        x = self.out_linear(x)
        return x

# %% [markdown]
# Model Training

# %%
model = Model(parameters)
decay_lr = tf.optimizers.schedules.ExponentialDecay(parameters['learning_rate'], 1000, 0.95)
optimizer = tf.optimizers.Adam(parameters['learning_rate'])
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

EPOCHS = 50
epoch, global_step, train = 0, 0, True
while epoch < EPOCHS: # train loop start
    epoch += 1
    print("Now in epoch: ", epoch)
    for texts, labels in dataset(isTraining=True, parameters=parameters):
        # print(texts.shape) # (parameters['batch_size'], parameters['max_seq_len'])
        with tf.GradientTape() as tape:
            logits = model(texts, training=True) # correpsond to call(self, inputs, training)
            loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits)
            loss = tf.reduce_mean(loss)
        optimizer.lr.assign(decay_lr(global_step)) # assign new learning rate
        grads = tape.gradient(loss, model.trainable_variables) # compute gradient
        grads, _ = tf.clip_by_global_norm(grads, parameters['clip_norm']) # clip gradient to avoid overfitting
        optimizer.apply_gradients(zip(grads, model.trainable_variables)) # update weights
        # print out training information
        if global_step % 10 == 0:
            y_pred = tf.argmax(logits, axis=-1)
            matrics = tf.keras.metrics.Accuracy()
            matrics.update_state(y_true=labels, y_pred=y_pred)
            accuracy = matrics.result().numpy()
            if accuracy > best_acc: best_acc = accuracy
            logger.info("Step {} | Acc: {:.4f} | Loss: {:.4f} | LR: {:.6f}".format(global_step, accuracy, loss.numpy().item(), optimizer.lr.numpy().item()))
        global_step += 1
# Out:
# EPOCH 1
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 0 | Acc: 0.3906 | Loss: 0.7016 | LR: 0.001000
# INFO:tensorflow:Step 10 | Acc: 0.5312 | Loss: 0.6854 | LR: 0.000999
# INFO:tensorflow:Step 20 | Acc: 0.4844 | Loss: 0.6966 | LR: 0.000999
# INFO:tensorflow:Step 30 | Acc: 0.6016 | Loss: 0.6815 | LR: 0.000998
# INFO:tensorflow:Step 40 | Acc: 0.6562 | Loss: 0.5978 | LR: 0.000998
# INFO:tensorflow:Step 50 | Acc: 0.6562 | Loss: 0.6292 | LR: 0.000997
# INFO:tensorflow:Step 60 | Acc: 0.6562 | Loss: 0.6200 | LR: 0.000997
# INFO:tensorflow:Step 70 | Acc: 0.6953 | Loss: 0.6291 | LR: 0.000996
# INFO:tensorflow:Step 80 | Acc: 0.7031 | Loss: 0.5678 | LR: 0.000996
# INFO:tensorflow:Step 90 | Acc: 0.6562 | Loss: 0.6437 | LR: 0.000995
# INFO:tensorflow:Step 100 | Acc: 0.5312 | Loss: 0.6891 | LR: 0.000995
# INFO:tensorflow:Step 110 | Acc: 0.5156 | Loss: 0.6939 | LR: 0.000994
# INFO:tensorflow:Step 120 | Acc: 0.6250 | Loss: 0.6593 | LR: 0.000994
# INFO:tensorflow:Step 130 | Acc: 0.6875 | Loss: 0.5867 | LR: 0.000993
# INFO:tensorflow:Step 140 | Acc: 0.6250 | Loss: 0.6457 | LR: 0.000993
# INFO:tensorflow:Step 150 | Acc: 0.6172 | Loss: 0.6351 | LR: 0.000992
# INFO:tensorflow:Step 160 | Acc: 0.5312 | Loss: 0.6915 | LR: 0.000992
# INFO:tensorflow:Step 170 | Acc: 0.5469 | Loss: 0.8815 | LR: 0.000991
# INFO:tensorflow:Step 180 | Acc: 0.5781 | Loss: 0.6857 | LR: 0.000991
# INFO:tensorflow:Step 190 | Acc: 0.5234 | Loss: 0.6851 | LR: 0.000990
# EPOCH 2
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 200 | Acc: 0.5938 | Loss: 0.6671 | LR: 0.000990
# INFO:tensorflow:Step 210 | Acc: 0.6562 | Loss: 0.6262 | LR: 0.000989
# INFO:tensorflow:Step 220 | Acc: 0.5859 | Loss: 0.6719 | LR: 0.000989
# INFO:tensorflow:Step 230 | Acc: 0.6094 | Loss: 0.7304 | LR: 0.000988
# INFO:tensorflow:Step 240 | Acc: 0.6797 | Loss: 0.6072 | LR: 0.000988
# INFO:tensorflow:Step 250 | Acc: 0.6016 | Loss: 0.6730 | LR: 0.000987
# INFO:tensorflow:Step 260 | Acc: 0.7656 | Loss: 0.5430 | LR: 0.000987
# INFO:tensorflow:Step 270 | Acc: 0.6406 | Loss: 0.6299 | LR: 0.000986
# INFO:tensorflow:Step 280 | Acc: 0.5547 | Loss: 0.6750 | LR: 0.000986
# INFO:tensorflow:Step 290 | Acc: 0.7109 | Loss: 0.5745 | LR: 0.000985
# INFO:tensorflow:Step 300 | Acc: 0.6641 | Loss: 0.5930 | LR: 0.000985
# INFO:tensorflow:Step 310 | Acc: 0.7266 | Loss: 0.5848 | LR: 0.000984
# INFO:tensorflow:Step 320 | Acc: 0.7422 | Loss: 0.5514 | LR: 0.000984
# INFO:tensorflow:Step 330 | Acc: 0.5078 | Loss: 0.6920 | LR: 0.000983
# INFO:tensorflow:Step 340 | Acc: 0.5312 | Loss: 0.6902 | LR: 0.000983
# INFO:tensorflow:Step 350 | Acc: 0.6797 | Loss: 0.6706 | LR: 0.000982
# INFO:tensorflow:Step 360 | Acc: 0.6016 | Loss: 0.6806 | LR: 0.000982
# INFO:tensorflow:Step 370 | Acc: 0.4766 | Loss: 0.6926 | LR: 0.000981
# INFO:tensorflow:Step 380 | Acc: 0.6328 | Loss: 0.6824 | LR: 0.000981
# INFO:tensorflow:Step 390 | Acc: 0.5859 | Loss: 0.6643 | LR: 0.000980
# EPOCH 3
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 400 | Acc: 0.6094 | Loss: 0.6610 | LR: 0.000980
# INFO:tensorflow:Step 410 | Acc: 0.6953 | Loss: 0.6312 | LR: 0.000979
# INFO:tensorflow:Step 420 | Acc: 0.6328 | Loss: 0.6138 | LR: 0.000979
# INFO:tensorflow:Step 430 | Acc: 0.5000 | Loss: 0.6921 | LR: 0.000978
# INFO:tensorflow:Step 440 | Acc: 0.5703 | Loss: 0.6517 | LR: 0.000978
# INFO:tensorflow:Step 450 | Acc: 0.6406 | Loss: 0.6122 | LR: 0.000977
# INFO:tensorflow:Step 460 | Acc: 0.6094 | Loss: 0.6639 | LR: 0.000977
# INFO:tensorflow:Step 470 | Acc: 0.7109 | Loss: 0.6358 | LR: 0.000976
# INFO:tensorflow:Step 480 | Acc: 0.6953 | Loss: 0.5929 | LR: 0.000976
# INFO:tensorflow:Step 490 | Acc: 0.6484 | Loss: 0.6157 | LR: 0.000975
# INFO:tensorflow:Step 500 | Acc: 0.7188 | Loss: 0.6355 | LR: 0.000975
# INFO:tensorflow:Step 510 | Acc: 0.5781 | Loss: 0.7014 | LR: 0.000974
# INFO:tensorflow:Step 520 | Acc: 0.6875 | Loss: 0.5785 | LR: 0.000974
# INFO:tensorflow:Step 530 | Acc: 0.7422 | Loss: 0.5693 | LR: 0.000973
# INFO:tensorflow:Step 540 | Acc: 0.7656 | Loss: 0.5114 | LR: 0.000973
# INFO:tensorflow:Step 550 | Acc: 0.6797 | Loss: 0.6521 | LR: 0.000972
# INFO:tensorflow:Step 560 | Acc: 0.8125 | Loss: 0.5340 | LR: 0.000972
# INFO:tensorflow:Step 570 | Acc: 0.7812 | Loss: 0.4714 | LR: 0.000971
# INFO:tensorflow:Step 580 | Acc: 0.7500 | Loss: 0.4824 | LR: 0.000971
# EPOCH 4
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 590 | Acc: 0.7344 | Loss: 0.5509 | LR: 0.000970
# INFO:tensorflow:Step 600 | Acc: 0.7266 | Loss: 0.5672 | LR: 0.000970
# INFO:tensorflow:Step 610 | Acc: 0.7656 | Loss: 0.5376 | LR: 0.000969
# INFO:tensorflow:Step 620 | Acc: 0.6953 | Loss: 0.5697 | LR: 0.000969
# INFO:tensorflow:Step 630 | Acc: 0.8203 | Loss: 0.5408 | LR: 0.000968
# INFO:tensorflow:Step 640 | Acc: 0.7812 | Loss: 0.5075 | LR: 0.000968
# INFO:tensorflow:Step 650 | Acc: 0.7500 | Loss: 0.5330 | LR: 0.000967
# INFO:tensorflow:Step 660 | Acc: 0.7422 | Loss: 0.5243 | LR: 0.000967
# INFO:tensorflow:Step 670 | Acc: 0.7344 | Loss: 0.5283 | LR: 0.000966
# INFO:tensorflow:Step 680 | Acc: 0.7734 | Loss: 0.4861 | LR: 0.000966
# INFO:tensorflow:Step 690 | Acc: 0.8047 | Loss: 0.4371 | LR: 0.000965
# INFO:tensorflow:Step 700 | Acc: 0.7422 | Loss: 0.4869 | LR: 0.000965
# INFO:tensorflow:Step 710 | Acc: 0.8281 | Loss: 0.4463 | LR: 0.000964
# INFO:tensorflow:Step 720 | Acc: 0.8125 | Loss: 0.4097 | LR: 0.000964
# INFO:tensorflow:Step 730 | Acc: 0.6953 | Loss: 0.5761 | LR: 0.000963
# INFO:tensorflow:Step 740 | Acc: 0.7891 | Loss: 0.4532 | LR: 0.000963
# INFO:tensorflow:Step 750 | Acc: 0.7422 | Loss: 0.5296 | LR: 0.000962
# INFO:tensorflow:Step 760 | Acc: 0.7500 | Loss: 0.5329 | LR: 0.000962
# INFO:tensorflow:Step 770 | Acc: 0.7578 | Loss: 0.5101 | LR: 0.000961
# INFO:tensorflow:Step 780 | Acc: 0.8281 | Loss: 0.4235 | LR: 0.000961
# EPOCH 5
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 790 | Acc: 0.7578 | Loss: 0.5346 | LR: 0.000960
# INFO:tensorflow:Step 800 | Acc: 0.8125 | Loss: 0.3961 | LR: 0.000960
# INFO:tensorflow:Step 810 | Acc: 0.8203 | Loss: 0.3823 | LR: 0.000959
# INFO:tensorflow:Step 820 | Acc: 0.7812 | Loss: 0.4889 | LR: 0.000959
# INFO:tensorflow:Step 830 | Acc: 0.8125 | Loss: 0.4785 | LR: 0.000958
# INFO:tensorflow:Step 840 | Acc: 0.7969 | Loss: 0.4669 | LR: 0.000958
# INFO:tensorflow:Step 850 | Acc: 0.7891 | Loss: 0.4554 | LR: 0.000957
# INFO:tensorflow:Step 860 | Acc: 0.8359 | Loss: 0.3734 | LR: 0.000957
# INFO:tensorflow:Step 870 | Acc: 0.7812 | Loss: 0.4526 | LR: 0.000956
# INFO:tensorflow:Step 880 | Acc: 0.7969 | Loss: 0.4353 | LR: 0.000956
# INFO:tensorflow:Step 890 | Acc: 0.8047 | Loss: 0.4463 | LR: 0.000955
# INFO:tensorflow:Step 900 | Acc: 0.8203 | Loss: 0.4771 | LR: 0.000955
# INFO:tensorflow:Step 910 | Acc: 0.8047 | Loss: 0.3885 | LR: 0.000954
# INFO:tensorflow:Step 920 | Acc: 0.8281 | Loss: 0.3913 | LR: 0.000954
# INFO:tensorflow:Step 930 | Acc: 0.8281 | Loss: 0.4627 | LR: 0.000953
# INFO:tensorflow:Step 940 | Acc: 0.8750 | Loss: 0.3644 | LR: 0.000953
# INFO:tensorflow:Step 950 | Acc: 0.8047 | Loss: 0.4867 | LR: 0.000952
# INFO:tensorflow:Step 960 | Acc: 0.8359 | Loss: 0.4027 | LR: 0.000952
# INFO:tensorflow:Step 970 | Acc: 0.7656 | Loss: 0.4944 | LR: 0.000951
# EPOCH 6
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 980 | Acc: 0.8359 | Loss: 0.4044 | LR: 0.000951
# INFO:tensorflow:Step 990 | Acc: 0.8516 | Loss: 0.3556 | LR: 0.000950
# INFO:tensorflow:Step 1000 | Acc: 0.8281 | Loss: 0.3806 | LR: 0.000950
# INFO:tensorflow:Step 1010 | Acc: 0.8281 | Loss: 0.4091 | LR: 0.000950
# INFO:tensorflow:Step 1020 | Acc: 0.8047 | Loss: 0.4290 | LR: 0.000949
# INFO:tensorflow:Step 1030 | Acc: 0.8672 | Loss: 0.3319 | LR: 0.000949
# INFO:tensorflow:Step 1040 | Acc: 0.8516 | Loss: 0.3936 | LR: 0.000948
# INFO:tensorflow:Step 1050 | Acc: 0.8516 | Loss: 0.3802 | LR: 0.000948
# INFO:tensorflow:Step 1060 | Acc: 0.7656 | Loss: 0.5396 | LR: 0.000947
# INFO:tensorflow:Step 1070 | Acc: 0.8203 | Loss: 0.3989 | LR: 0.000947
# INFO:tensorflow:Step 1080 | Acc: 0.8047 | Loss: 0.3982 | LR: 0.000946
# INFO:tensorflow:Step 1090 | Acc: 0.8672 | Loss: 0.3474 | LR: 0.000946
# INFO:tensorflow:Step 1100 | Acc: 0.8125 | Loss: 0.4068 | LR: 0.000945
# INFO:tensorflow:Step 1110 | Acc: 0.8516 | Loss: 0.3710 | LR: 0.000945
# INFO:tensorflow:Step 1120 | Acc: 0.7188 | Loss: 0.6026 | LR: 0.000944
# INFO:tensorflow:Step 1130 | Acc: 0.8438 | Loss: 0.3695 | LR: 0.000944
# INFO:tensorflow:Step 1140 | Acc: 0.8672 | Loss: 0.3351 | LR: 0.000943
# INFO:tensorflow:Step 1150 | Acc: 0.8594 | Loss: 0.3300 | LR: 0.000943
# INFO:tensorflow:Step 1160 | Acc: 0.7891 | Loss: 0.4049 | LR: 0.000942
# INFO:tensorflow:Step 1170 | Acc: 0.7969 | Loss: 0.3774 | LR: 0.000942
# EPOCH 7
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 1180 | Acc: 0.7422 | Loss: 0.4891 | LR: 0.000941
# INFO:tensorflow:Step 1190 | Acc: 0.8672 | Loss: 0.2830 | LR: 0.000941
# INFO:tensorflow:Step 1200 | Acc: 0.8047 | Loss: 0.4214 | LR: 0.000940
# INFO:tensorflow:Step 1210 | Acc: 0.8438 | Loss: 0.3698 | LR: 0.000940
# INFO:tensorflow:Step 1220 | Acc: 0.8516 | Loss: 0.3742 | LR: 0.000939
# INFO:tensorflow:Step 1230 | Acc: 0.8438 | Loss: 0.3654 | LR: 0.000939
# INFO:tensorflow:Step 1240 | Acc: 0.8281 | Loss: 0.3700 | LR: 0.000938
# INFO:tensorflow:Step 1250 | Acc: 0.8438 | Loss: 0.3413 | LR: 0.000938
# INFO:tensorflow:Step 1260 | Acc: 0.8828 | Loss: 0.3281 | LR: 0.000937
# INFO:tensorflow:Step 1270 | Acc: 0.8203 | Loss: 0.3712 | LR: 0.000937
# INFO:tensorflow:Step 1280 | Acc: 0.8281 | Loss: 0.3389 | LR: 0.000936
# INFO:tensorflow:Step 1290 | Acc: 0.8828 | Loss: 0.2847 | LR: 0.000936
# INFO:tensorflow:Step 1300 | Acc: 0.7969 | Loss: 0.4840 | LR: 0.000935
# INFO:tensorflow:Step 1310 | Acc: 0.7812 | Loss: 0.3664 | LR: 0.000935
# INFO:tensorflow:Step 1320 | Acc: 0.8359 | Loss: 0.3217 | LR: 0.000935
# INFO:tensorflow:Step 1330 | Acc: 0.8516 | Loss: 0.3700 | LR: 0.000934
# INFO:tensorflow:Step 1340 | Acc: 0.8047 | Loss: 0.3756 | LR: 0.000934
# INFO:tensorflow:Step 1350 | Acc: 0.8281 | Loss: 0.4071 | LR: 0.000933
# INFO:tensorflow:Step 1360 | Acc: 0.8594 | Loss: 0.3279 | LR: 0.000933
# INFO:tensorflow:Step 1370 | Acc: 0.8359 | Loss: 0.3784 | LR: 0.000932
# EPOCH 8
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 1380 | Acc: 0.8203 | Loss: 0.3778 | LR: 0.000932
# INFO:tensorflow:Step 1390 | Acc: 0.8203 | Loss: 0.4469 | LR: 0.000931
# INFO:tensorflow:Step 1400 | Acc: 0.8828 | Loss: 0.3402 | LR: 0.000931
# INFO:tensorflow:Step 1410 | Acc: 0.8359 | Loss: 0.3557 | LR: 0.000930
# INFO:tensorflow:Step 1420 | Acc: 0.8203 | Loss: 0.4391 | LR: 0.000930
# INFO:tensorflow:Step 1430 | Acc: 0.8359 | Loss: 0.3710 | LR: 0.000929
# INFO:tensorflow:Step 1440 | Acc: 0.8359 | Loss: 0.3983 | LR: 0.000929
# INFO:tensorflow:Step 1450 | Acc: 0.8203 | Loss: 0.3819 | LR: 0.000928
# INFO:tensorflow:Step 1460 | Acc: 0.8281 | Loss: 0.3657 | LR: 0.000928
# INFO:tensorflow:Step 1470 | Acc: 0.7891 | Loss: 0.4103 | LR: 0.000927
# INFO:tensorflow:Step 1480 | Acc: 0.8125 | Loss: 0.4635 | LR: 0.000927
# INFO:tensorflow:Step 1490 | Acc: 0.8438 | Loss: 0.3330 | LR: 0.000926
# INFO:tensorflow:Step 1500 | Acc: 0.8906 | Loss: 0.2849 | LR: 0.000926
# INFO:tensorflow:Step 1510 | Acc: 0.7734 | Loss: 0.4602 | LR: 0.000925
# INFO:tensorflow:Step 1520 | Acc: 0.7734 | Loss: 0.4765 | LR: 0.000925
# INFO:tensorflow:Step 1530 | Acc: 0.8594 | Loss: 0.3124 | LR: 0.000925
# INFO:tensorflow:Step 1540 | Acc: 0.8750 | Loss: 0.2708 | LR: 0.000924
# INFO:tensorflow:Step 1550 | Acc: 0.7891 | Loss: 0.4382 | LR: 0.000924
# INFO:tensorflow:Step 1560 | Acc: 0.8516 | Loss: 0.2873 | LR: 0.000923
# EPOCH 9
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 1570 | Acc: 0.8281 | Loss: 0.3356 | LR: 0.000923
# INFO:tensorflow:Step 1580 | Acc: 0.7891 | Loss: 0.4014 | LR: 0.000922
# INFO:tensorflow:Step 1590 | Acc: 0.8750 | Loss: 0.3282 | LR: 0.000922
# INFO:tensorflow:Step 1600 | Acc: 0.8672 | Loss: 0.3149 | LR: 0.000921
# INFO:tensorflow:Step 1610 | Acc: 0.8750 | Loss: 0.3084 | LR: 0.000921
# INFO:tensorflow:Step 1620 | Acc: 0.8047 | Loss: 0.4243 | LR: 0.000920
# INFO:tensorflow:Step 1630 | Acc: 0.8203 | Loss: 0.3949 | LR: 0.000920
# INFO:tensorflow:Step 1640 | Acc: 0.7891 | Loss: 0.4537 | LR: 0.000919
# INFO:tensorflow:Step 1650 | Acc: 0.8438 | Loss: 0.3600 | LR: 0.000919
# INFO:tensorflow:Step 1660 | Acc: 0.8906 | Loss: 0.2860 | LR: 0.000918
# INFO:tensorflow:Step 1670 | Acc: 0.8906 | Loss: 0.2575 | LR: 0.000918
# INFO:tensorflow:Step 1680 | Acc: 0.8594 | Loss: 0.3375 | LR: 0.000917
# INFO:tensorflow:Step 1690 | Acc: 0.8516 | Loss: 0.3250 | LR: 0.000917
# INFO:tensorflow:Step 1700 | Acc: 0.8984 | Loss: 0.2917 | LR: 0.000916
# INFO:tensorflow:Step 1710 | Acc: 0.8281 | Loss: 0.4128 | LR: 0.000916
# INFO:tensorflow:Step 1720 | Acc: 0.8203 | Loss: 0.3829 | LR: 0.000916
# INFO:tensorflow:Step 1730 | Acc: 0.8438 | Loss: 0.3813 | LR: 0.000915
# INFO:tensorflow:Step 1740 | Acc: 0.8516 | Loss: 0.3410 | LR: 0.000915
# INFO:tensorflow:Step 1750 | Acc: 0.8359 | Loss: 0.3479 | LR: 0.000914
# INFO:tensorflow:Step 1760 | Acc: 0.8359 | Loss: 0.3709 | LR: 0.000914
# EPOCH 10
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 1770 | Acc: 0.8906 | Loss: 0.2774 | LR: 0.000913
# INFO:tensorflow:Step 1780 | Acc: 0.8359 | Loss: 0.3773 | LR: 0.000913
# INFO:tensorflow:Step 1790 | Acc: 0.7812 | Loss: 0.4448 | LR: 0.000912
# INFO:tensorflow:Step 1800 | Acc: 0.8125 | Loss: 0.3940 | LR: 0.000912
# INFO:tensorflow:Step 1810 | Acc: 0.8047 | Loss: 0.4173 | LR: 0.000911
# INFO:tensorflow:Step 1820 | Acc: 0.8359 | Loss: 0.3415 | LR: 0.000911
# INFO:tensorflow:Step 1830 | Acc: 0.8672 | Loss: 0.3179 | LR: 0.000910
# INFO:tensorflow:Step 1840 | Acc: 0.8125 | Loss: 0.3357 | LR: 0.000910
# INFO:tensorflow:Step 1850 | Acc: 0.7969 | Loss: 0.4053 | LR: 0.000909
# INFO:tensorflow:Step 1860 | Acc: 0.8125 | Loss: 0.4210 | LR: 0.000909
# INFO:tensorflow:Step 1870 | Acc: 0.8594 | Loss: 0.3746 | LR: 0.000909
# INFO:tensorflow:Step 1880 | Acc: 0.8594 | Loss: 0.3473 | LR: 0.000908
# INFO:tensorflow:Step 1890 | Acc: 0.8125 | Loss: 0.4135 | LR: 0.000908
# INFO:tensorflow:Step 1900 | Acc: 0.8594 | Loss: 0.2959 | LR: 0.000907
# INFO:tensorflow:Step 1910 | Acc: 0.8984 | Loss: 0.3017 | LR: 0.000907
# INFO:tensorflow:Step 1920 | Acc: 0.8828 | Loss: 0.2971 | LR: 0.000906
# INFO:tensorflow:Step 1930 | Acc: 0.8594 | Loss: 0.3294 | LR: 0.000906
# INFO:tensorflow:Step 1940 | Acc: 0.7812 | Loss: 0.4659 | LR: 0.000905
# INFO:tensorflow:Step 1950 | Acc: 0.7891 | Loss: 0.3782 | LR: 0.000905
# EPOCH 11
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 1960 | Acc: 0.8750 | Loss: 0.3162 | LR: 0.000904
# INFO:tensorflow:Step 1970 | Acc: 0.8516 | Loss: 0.3223 | LR: 0.000904
# INFO:tensorflow:Step 1980 | Acc: 0.8672 | Loss: 0.2584 | LR: 0.000903
# INFO:tensorflow:Step 1990 | Acc: 0.8984 | Loss: 0.2880 | LR: 0.000903
# INFO:tensorflow:Step 2000 | Acc: 0.8516 | Loss: 0.3687 | LR: 0.000902
# INFO:tensorflow:Step 2010 | Acc: 0.8672 | Loss: 0.2678 | LR: 0.000902
# INFO:tensorflow:Step 2020 | Acc: 0.8594 | Loss: 0.3196 | LR: 0.000902
# INFO:tensorflow:Step 2030 | Acc: 0.8125 | Loss: 0.3739 | LR: 0.000901
# INFO:tensorflow:Step 2040 | Acc: 0.8281 | Loss: 0.3960 | LR: 0.000901
# INFO:tensorflow:Step 2050 | Acc: 0.8359 | Loss: 0.3407 | LR: 0.000900
# INFO:tensorflow:Step 2060 | Acc: 0.8359 | Loss: 0.3662 | LR: 0.000900
# INFO:tensorflow:Step 2070 | Acc: 0.8594 | Loss: 0.3105 | LR: 0.000899
# INFO:tensorflow:Step 2080 | Acc: 0.8672 | Loss: 0.3211 | LR: 0.000899
# INFO:tensorflow:Step 2090 | Acc: 0.8594 | Loss: 0.3514 | LR: 0.000898
# INFO:tensorflow:Step 2100 | Acc: 0.8359 | Loss: 0.3327 | LR: 0.000898
# INFO:tensorflow:Step 2110 | Acc: 0.8281 | Loss: 0.3818 | LR: 0.000897
# INFO:tensorflow:Step 2120 | Acc: 0.8438 | Loss: 0.3141 | LR: 0.000897
# INFO:tensorflow:Step 2130 | Acc: 0.7891 | Loss: 0.4003 | LR: 0.000897
# INFO:tensorflow:Step 2140 | Acc: 0.8516 | Loss: 0.2895 | LR: 0.000896
# INFO:tensorflow:Step 2150 | Acc: 0.8828 | Loss: 0.3307 | LR: 0.000896
# EPOCH 12
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 2160 | Acc: 0.8438 | Loss: 0.3567 | LR: 0.000895
# INFO:tensorflow:Step 2170 | Acc: 0.8672 | Loss: 0.3056 | LR: 0.000895
# INFO:tensorflow:Step 2180 | Acc: 0.8359 | Loss: 0.4229 | LR: 0.000894
# INFO:tensorflow:Step 2190 | Acc: 0.8750 | Loss: 0.2640 | LR: 0.000894
# INFO:tensorflow:Step 2200 | Acc: 0.8750 | Loss: 0.2893 | LR: 0.000893
# INFO:tensorflow:Step 2210 | Acc: 0.8516 | Loss: 0.3767 | LR: 0.000893
# INFO:tensorflow:Step 2220 | Acc: 0.8125 | Loss: 0.4069 | LR: 0.000892
# INFO:tensorflow:Step 2230 | Acc: 0.8438 | Loss: 0.3705 | LR: 0.000892
# INFO:tensorflow:Step 2240 | Acc: 0.8984 | Loss: 0.2703 | LR: 0.000891
# INFO:tensorflow:Step 2250 | Acc: 0.8438 | Loss: 0.2826 | LR: 0.000891
# INFO:tensorflow:Step 2260 | Acc: 0.8984 | Loss: 0.2685 | LR: 0.000891
# INFO:tensorflow:Step 2270 | Acc: 0.8672 | Loss: 0.3139 | LR: 0.000890
# INFO:tensorflow:Step 2280 | Acc: 0.8047 | Loss: 0.4375 | LR: 0.000890
# INFO:tensorflow:Step 2290 | Acc: 0.8672 | Loss: 0.3055 | LR: 0.000889
# INFO:tensorflow:Step 2300 | Acc: 0.8906 | Loss: 0.2521 | LR: 0.000889
# INFO:tensorflow:Step 2310 | Acc: 0.8750 | Loss: 0.3093 | LR: 0.000888
# INFO:tensorflow:Step 2320 | Acc: 0.8672 | Loss: 0.3664 | LR: 0.000888
# INFO:tensorflow:Step 2330 | Acc: 0.8594 | Loss: 0.3556 | LR: 0.000887
# INFO:tensorflow:Step 2340 | Acc: 0.8672 | Loss: 0.3281 | LR: 0.000887
# INFO:tensorflow:Step 2350 | Acc: 0.9297 | Loss: 0.2003 | LR: 0.000886
# EPOCH 13
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 2360 | Acc: 0.9062 | Loss: 0.2083 | LR: 0.000886
# INFO:tensorflow:Step 2370 | Acc: 0.8906 | Loss: 0.3069 | LR: 0.000886
# INFO:tensorflow:Step 2380 | Acc: 0.9219 | Loss: 0.2365 | LR: 0.000885
# INFO:tensorflow:Step 2390 | Acc: 0.9062 | Loss: 0.2435 | LR: 0.000885
# INFO:tensorflow:Step 2400 | Acc: 0.8125 | Loss: 0.3451 | LR: 0.000884
# INFO:tensorflow:Step 2410 | Acc: 0.9141 | Loss: 0.2714 | LR: 0.000884
# INFO:tensorflow:Step 2420 | Acc: 0.8828 | Loss: 0.2628 | LR: 0.000883
# INFO:tensorflow:Step 2430 | Acc: 0.7891 | Loss: 0.4874 | LR: 0.000883
# INFO:tensorflow:Step 2440 | Acc: 0.8281 | Loss: 0.3902 | LR: 0.000882
# INFO:tensorflow:Step 2450 | Acc: 0.9062 | Loss: 0.3243 | LR: 0.000882
# INFO:tensorflow:Step 2460 | Acc: 0.8438 | Loss: 0.3704 | LR: 0.000881
# INFO:tensorflow:Step 2470 | Acc: 0.8281 | Loss: 0.2707 | LR: 0.000881
# INFO:tensorflow:Step 2480 | Acc: 0.8672 | Loss: 0.3325 | LR: 0.000881
# INFO:tensorflow:Step 2490 | Acc: 0.8438 | Loss: 0.3124 | LR: 0.000880
# INFO:tensorflow:Step 2500 | Acc: 0.8750 | Loss: 0.2790 | LR: 0.000880
# INFO:tensorflow:Step 2510 | Acc: 0.9219 | Loss: 0.2600 | LR: 0.000879
# INFO:tensorflow:Step 2520 | Acc: 0.8203 | Loss: 0.4565 | LR: 0.000879
# INFO:tensorflow:Step 2530 | Acc: 0.8750 | Loss: 0.3060 | LR: 0.000878
# INFO:tensorflow:Step 2540 | Acc: 0.8438 | Loss: 0.3936 | LR: 0.000878
# EPOCH 14
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 2550 | Acc: 0.8438 | Loss: 0.3284 | LR: 0.000877
# INFO:tensorflow:Step 2560 | Acc: 0.8750 | Loss: 0.3067 | LR: 0.000877
# INFO:tensorflow:Step 2570 | Acc: 0.8438 | Loss: 0.3269 | LR: 0.000876
# INFO:tensorflow:Step 2580 | Acc: 0.8984 | Loss: 0.2827 | LR: 0.000876
# INFO:tensorflow:Step 2590 | Acc: 0.8828 | Loss: 0.2894 | LR: 0.000876
# INFO:tensorflow:Step 2600 | Acc: 0.8594 | Loss: 0.3414 | LR: 0.000875
# INFO:tensorflow:Step 2610 | Acc: 0.8359 | Loss: 0.3231 | LR: 0.000875
# INFO:tensorflow:Step 2620 | Acc: 0.8672 | Loss: 0.3161 | LR: 0.000874
# INFO:tensorflow:Step 2630 | Acc: 0.8594 | Loss: 0.2887 | LR: 0.000874
# INFO:tensorflow:Step 2640 | Acc: 0.8594 | Loss: 0.3960 | LR: 0.000873
# INFO:tensorflow:Step 2650 | Acc: 0.8828 | Loss: 0.2913 | LR: 0.000873
# INFO:tensorflow:Step 2660 | Acc: 0.8516 | Loss: 0.3235 | LR: 0.000872
# INFO:tensorflow:Step 2670 | Acc: 0.8516 | Loss: 0.3728 | LR: 0.000872
# INFO:tensorflow:Step 2680 | Acc: 0.8359 | Loss: 0.3440 | LR: 0.000872
# INFO:tensorflow:Step 2690 | Acc: 0.8672 | Loss: 0.3128 | LR: 0.000871
# INFO:tensorflow:Step 2700 | Acc: 0.8672 | Loss: 0.2855 | LR: 0.000871
# INFO:tensorflow:Step 2710 | Acc: 0.9062 | Loss: 0.2527 | LR: 0.000870
# INFO:tensorflow:Step 2720 | Acc: 0.8984 | Loss: 0.2220 | LR: 0.000870
# INFO:tensorflow:Step 2730 | Acc: 0.9219 | Loss: 0.2367 | LR: 0.000869
# INFO:tensorflow:Step 2740 | Acc: 0.8984 | Loss: 0.3119 | LR: 0.000869
# EPOCH 15
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 2750 | Acc: 0.8359 | Loss: 0.3481 | LR: 0.000868
# INFO:tensorflow:Step 2760 | Acc: 0.8828 | Loss: 0.2793 | LR: 0.000868
# INFO:tensorflow:Step 2770 | Acc: 0.9219 | Loss: 0.2550 | LR: 0.000868
# INFO:tensorflow:Step 2780 | Acc: 0.8906 | Loss: 0.3033 | LR: 0.000867
# INFO:tensorflow:Step 2790 | Acc: 0.8047 | Loss: 0.4324 | LR: 0.000867
# INFO:tensorflow:Step 2800 | Acc: 0.9062 | Loss: 0.2739 | LR: 0.000866
# INFO:tensorflow:Step 2810 | Acc: 0.8906 | Loss: 0.2317 | LR: 0.000866
# INFO:tensorflow:Step 2820 | Acc: 0.9375 | Loss: 0.2394 | LR: 0.000865
# INFO:tensorflow:Step 2830 | Acc: 0.8906 | Loss: 0.2638 | LR: 0.000865
# INFO:tensorflow:Step 2840 | Acc: 0.8672 | Loss: 0.3218 | LR: 0.000864
# INFO:tensorflow:Step 2850 | Acc: 0.8828 | Loss: 0.2400 | LR: 0.000864
# INFO:tensorflow:Step 2860 | Acc: 0.8984 | Loss: 0.2932 | LR: 0.000864
# INFO:tensorflow:Step 2870 | Acc: 0.9375 | Loss: 0.1714 | LR: 0.000863
# INFO:tensorflow:Step 2880 | Acc: 0.9141 | Loss: 0.2464 | LR: 0.000863
# INFO:tensorflow:Step 2890 | Acc: 0.8828 | Loss: 0.2947 | LR: 0.000862
# INFO:tensorflow:Step 2900 | Acc: 0.8672 | Loss: 0.2887 | LR: 0.000862
# INFO:tensorflow:Step 2910 | Acc: 0.9062 | Loss: 0.2533 | LR: 0.000861
# INFO:tensorflow:Step 2920 | Acc: 0.8828 | Loss: 0.3103 | LR: 0.000861
# INFO:tensorflow:Step 2930 | Acc: 0.7969 | Loss: 0.3942 | LR: 0.000860
# EPOCH 16
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 2940 | Acc: 0.8750 | Loss: 0.2919 | LR: 0.000860
# INFO:tensorflow:Step 2950 | Acc: 0.8984 | Loss: 0.2776 | LR: 0.000860
# INFO:tensorflow:Step 2960 | Acc: 0.8906 | Loss: 0.2422 | LR: 0.000859
# INFO:tensorflow:Step 2970 | Acc: 0.8281 | Loss: 0.3911 | LR: 0.000859
# INFO:tensorflow:Step 2980 | Acc: 0.8672 | Loss: 0.3046 | LR: 0.000858
# INFO:tensorflow:Step 2990 | Acc: 0.8906 | Loss: 0.3017 | LR: 0.000858
# INFO:tensorflow:Step 3000 | Acc: 0.8750 | Loss: 0.2953 | LR: 0.000857
# INFO:tensorflow:Step 3010 | Acc: 0.8516 | Loss: 0.3437 | LR: 0.000857
# INFO:tensorflow:Step 3020 | Acc: 0.9141 | Loss: 0.2246 | LR: 0.000856
# INFO:tensorflow:Step 3030 | Acc: 0.8828 | Loss: 0.2588 | LR: 0.000856
# INFO:tensorflow:Step 3040 | Acc: 0.8359 | Loss: 0.3298 | LR: 0.000856
# INFO:tensorflow:Step 3050 | Acc: 0.8828 | Loss: 0.2869 | LR: 0.000855
# INFO:tensorflow:Step 3060 | Acc: 0.8906 | Loss: 0.2899 | LR: 0.000855
# INFO:tensorflow:Step 3070 | Acc: 0.8828 | Loss: 0.2846 | LR: 0.000854
# INFO:tensorflow:Step 3080 | Acc: 0.8672 | Loss: 0.3151 | LR: 0.000854
# INFO:tensorflow:Step 3090 | Acc: 0.8984 | Loss: 0.2686 | LR: 0.000853
# INFO:tensorflow:Step 3100 | Acc: 0.8906 | Loss: 0.2599 | LR: 0.000853
# INFO:tensorflow:Step 3110 | Acc: 0.9062 | Loss: 0.2244 | LR: 0.000853
# INFO:tensorflow:Step 3120 | Acc: 0.9219 | Loss: 0.3137 | LR: 0.000852
# INFO:tensorflow:Step 3130 | Acc: 0.9297 | Loss: 0.2256 | LR: 0.000852
# EPOCH 17
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 3140 | Acc: 0.8359 | Loss: 0.3314 | LR: 0.000851
# INFO:tensorflow:Step 3150 | Acc: 0.8594 | Loss: 0.3270 | LR: 0.000851
# INFO:tensorflow:Step 3160 | Acc: 0.9219 | Loss: 0.2009 | LR: 0.000850
# INFO:tensorflow:Step 3170 | Acc: 0.8828 | Loss: 0.2823 | LR: 0.000850
# INFO:tensorflow:Step 3180 | Acc: 0.8672 | Loss: 0.3104 | LR: 0.000849
# INFO:tensorflow:Step 3190 | Acc: 0.8828 | Loss: 0.2938 | LR: 0.000849
# INFO:tensorflow:Step 3200 | Acc: 0.8672 | Loss: 0.2826 | LR: 0.000849
# INFO:tensorflow:Step 3210 | Acc: 0.8672 | Loss: 0.3100 | LR: 0.000848
# INFO:tensorflow:Step 3220 | Acc: 0.8906 | Loss: 0.2841 | LR: 0.000848
# INFO:tensorflow:Step 3230 | Acc: 0.9375 | Loss: 0.1938 | LR: 0.000847
# INFO:tensorflow:Step 3240 | Acc: 0.8906 | Loss: 0.2314 | LR: 0.000847
# INFO:tensorflow:Step 3250 | Acc: 0.8984 | Loss: 0.2449 | LR: 0.000846
# INFO:tensorflow:Step 3260 | Acc: 0.8516 | Loss: 0.3833 | LR: 0.000846
# INFO:tensorflow:Step 3270 | Acc: 0.8516 | Loss: 0.3532 | LR: 0.000846
# INFO:tensorflow:Step 3280 | Acc: 0.8984 | Loss: 0.2398 | LR: 0.000845
# INFO:tensorflow:Step 3290 | Acc: 0.8906 | Loss: 0.3097 | LR: 0.000845
# INFO:tensorflow:Step 3300 | Acc: 0.8984 | Loss: 0.2217 | LR: 0.000844
# INFO:tensorflow:Step 3310 | Acc: 0.8750 | Loss: 0.3140 | LR: 0.000844
# INFO:tensorflow:Step 3320 | Acc: 0.9453 | Loss: 0.1720 | LR: 0.000843
# INFO:tensorflow:Step 3330 | Acc: 0.8828 | Loss: 0.2382 | LR: 0.000843
# EPOCH 18
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 3340 | Acc: 0.9141 | Loss: 0.1849 | LR: 0.000843
# INFO:tensorflow:Step 3350 | Acc: 0.8516 | Loss: 0.2857 | LR: 0.000842
# INFO:tensorflow:Step 3360 | Acc: 0.7969 | Loss: 0.3623 | LR: 0.000842
# INFO:tensorflow:Step 3370 | Acc: 0.8672 | Loss: 0.2708 | LR: 0.000841
# INFO:tensorflow:Step 3380 | Acc: 0.8828 | Loss: 0.2380 | LR: 0.000841
# INFO:tensorflow:Step 3390 | Acc: 0.8828 | Loss: 0.3521 | LR: 0.000840
# INFO:tensorflow:Step 3400 | Acc: 0.8359 | Loss: 0.3166 | LR: 0.000840
# INFO:tensorflow:Step 3410 | Acc: 0.8984 | Loss: 0.2399 | LR: 0.000840
# INFO:tensorflow:Step 3420 | Acc: 0.8984 | Loss: 0.2192 | LR: 0.000839
# INFO:tensorflow:Step 3430 | Acc: 0.9141 | Loss: 0.1995 | LR: 0.000839
# INFO:tensorflow:Step 3440 | Acc: 0.8750 | Loss: 0.2703 | LR: 0.000838
# INFO:tensorflow:Step 3450 | Acc: 0.8438 | Loss: 0.3664 | LR: 0.000838
# INFO:tensorflow:Step 3460 | Acc: 0.8594 | Loss: 0.3477 | LR: 0.000837
# INFO:tensorflow:Step 3470 | Acc: 0.8672 | Loss: 0.2901 | LR: 0.000837
# INFO:tensorflow:Step 3480 | Acc: 0.8906 | Loss: 0.2318 | LR: 0.000837
# INFO:tensorflow:Step 3490 | Acc: 0.9375 | Loss: 0.1883 | LR: 0.000836
# INFO:tensorflow:Step 3500 | Acc: 0.8984 | Loss: 0.2552 | LR: 0.000836
# INFO:tensorflow:Step 3510 | Acc: 0.8594 | Loss: 0.3520 | LR: 0.000835
# INFO:tensorflow:Step 3520 | Acc: 0.8750 | Loss: 0.3165 | LR: 0.000835
# EPOCH 19
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 3530 | Acc: 0.8828 | Loss: 0.2951 | LR: 0.000834
# INFO:tensorflow:Step 3540 | Acc: 0.9062 | Loss: 0.2160 | LR: 0.000834
# INFO:tensorflow:Step 3550 | Acc: 0.8750 | Loss: 0.2547 | LR: 0.000834
# INFO:tensorflow:Step 3560 | Acc: 0.8672 | Loss: 0.2707 | LR: 0.000833
# INFO:tensorflow:Step 3570 | Acc: 0.9062 | Loss: 0.2160 | LR: 0.000833
# INFO:tensorflow:Step 3580 | Acc: 0.9453 | Loss: 0.1761 | LR: 0.000832
# INFO:tensorflow:Step 3590 | Acc: 0.8516 | Loss: 0.3148 | LR: 0.000832
# INFO:tensorflow:Step 3600 | Acc: 0.8828 | Loss: 0.2661 | LR: 0.000831
# INFO:tensorflow:Step 3610 | Acc: 0.8984 | Loss: 0.2567 | LR: 0.000831
# INFO:tensorflow:Step 3620 | Acc: 0.8750 | Loss: 0.3013 | LR: 0.000831
# INFO:tensorflow:Step 3630 | Acc: 0.8828 | Loss: 0.2450 | LR: 0.000830
# INFO:tensorflow:Step 3640 | Acc: 0.9062 | Loss: 0.2202 | LR: 0.000830
# INFO:tensorflow:Step 3650 | Acc: 0.9219 | Loss: 0.2110 | LR: 0.000829
# INFO:tensorflow:Step 3660 | Acc: 0.8750 | Loss: 0.2607 | LR: 0.000829
# INFO:tensorflow:Step 3670 | Acc: 0.9141 | Loss: 0.2000 | LR: 0.000828
# INFO:tensorflow:Step 3680 | Acc: 0.8438 | Loss: 0.2839 | LR: 0.000828
# INFO:tensorflow:Step 3690 | Acc: 0.8516 | Loss: 0.3435 | LR: 0.000828
# INFO:tensorflow:Step 3700 | Acc: 0.9141 | Loss: 0.2005 | LR: 0.000827
# INFO:tensorflow:Step 3710 | Acc: 0.8672 | Loss: 0.2824 | LR: 0.000827
# INFO:tensorflow:Step 3720 | Acc: 0.8750 | Loss: 0.2754 | LR: 0.000826
# EPOCH 20
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 3730 | Acc: 0.8984 | Loss: 0.2012 | LR: 0.000826
# INFO:tensorflow:Step 3740 | Acc: 0.8906 | Loss: 0.2612 | LR: 0.000825
# INFO:tensorflow:Step 3750 | Acc: 0.9297 | Loss: 0.2391 | LR: 0.000825
# INFO:tensorflow:Step 3760 | Acc: 0.9219 | Loss: 0.2020 | LR: 0.000825
# INFO:tensorflow:Step 3770 | Acc: 0.9531 | Loss: 0.1428 | LR: 0.000824
# INFO:tensorflow:Step 3780 | Acc: 0.9297 | Loss: 0.2084 | LR: 0.000824
# INFO:tensorflow:Step 3790 | Acc: 0.8906 | Loss: 0.2703 | LR: 0.000823
# INFO:tensorflow:Step 3800 | Acc: 0.8984 | Loss: 0.2516 | LR: 0.000823
# INFO:tensorflow:Step 3810 | Acc: 0.8594 | Loss: 0.2920 | LR: 0.000822
# INFO:tensorflow:Step 3820 | Acc: 0.9062 | Loss: 0.2652 | LR: 0.000822
# INFO:tensorflow:Step 3830 | Acc: 0.9297 | Loss: 0.2061 | LR: 0.000822
# INFO:tensorflow:Step 3840 | Acc: 0.8594 | Loss: 0.3479 | LR: 0.000821
# INFO:tensorflow:Step 3850 | Acc: 0.9141 | Loss: 0.1963 | LR: 0.000821
# INFO:tensorflow:Step 3860 | Acc: 0.8906 | Loss: 0.2725 | LR: 0.000820
# INFO:tensorflow:Step 3870 | Acc: 0.8828 | Loss: 0.3110 | LR: 0.000820
# INFO:tensorflow:Step 3880 | Acc: 0.8203 | Loss: 0.3393 | LR: 0.000820
# INFO:tensorflow:Step 3890 | Acc: 0.8828 | Loss: 0.2751 | LR: 0.000819
# INFO:tensorflow:Step 3900 | Acc: 0.8438 | Loss: 0.2971 | LR: 0.000819
# INFO:tensorflow:Step 3910 | Acc: 0.9062 | Loss: 0.2968 | LR: 0.000818
# EPOCH 21
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 3920 | Acc: 0.8828 | Loss: 0.2500 | LR: 0.000818
# INFO:tensorflow:Step 3930 | Acc: 0.8516 | Loss: 0.3482 | LR: 0.000817
# INFO:tensorflow:Step 3940 | Acc: 0.8906 | Loss: 0.2677 | LR: 0.000817
# INFO:tensorflow:Step 3950 | Acc: 0.8672 | Loss: 0.2600 | LR: 0.000817
# INFO:tensorflow:Step 3960 | Acc: 0.9062 | Loss: 0.2196 | LR: 0.000816
# INFO:tensorflow:Step 3970 | Acc: 0.8906 | Loss: 0.2135 | LR: 0.000816
# INFO:tensorflow:Step 3980 | Acc: 0.9062 | Loss: 0.2423 | LR: 0.000815
# INFO:tensorflow:Step 3990 | Acc: 0.8672 | Loss: 0.3349 | LR: 0.000815
# INFO:tensorflow:Step 4000 | Acc: 0.9141 | Loss: 0.3015 | LR: 0.000815
# INFO:tensorflow:Step 4010 | Acc: 0.8594 | Loss: 0.3558 | LR: 0.000814
# INFO:tensorflow:Step 4020 | Acc: 0.8906 | Loss: 0.2717 | LR: 0.000814
# INFO:tensorflow:Step 4030 | Acc: 0.8672 | Loss: 0.3295 | LR: 0.000813
# INFO:tensorflow:Step 4040 | Acc: 0.8984 | Loss: 0.2536 | LR: 0.000813
# INFO:tensorflow:Step 4050 | Acc: 0.8594 | Loss: 0.3015 | LR: 0.000812
# INFO:tensorflow:Step 4060 | Acc: 0.8672 | Loss: 0.2881 | LR: 0.000812
# INFO:tensorflow:Step 4070 | Acc: 0.9219 | Loss: 0.1982 | LR: 0.000812
# INFO:tensorflow:Step 4080 | Acc: 0.9062 | Loss: 0.2024 | LR: 0.000811
# INFO:tensorflow:Step 4090 | Acc: 0.9062 | Loss: 0.2483 | LR: 0.000811
# INFO:tensorflow:Step 4100 | Acc: 0.9375 | Loss: 0.2155 | LR: 0.000810
# INFO:tensorflow:Step 4110 | Acc: 0.8828 | Loss: 0.2646 | LR: 0.000810
# EPOCH 22
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 4120 | Acc: 0.8828 | Loss: 0.2670 | LR: 0.000810
# INFO:tensorflow:Step 4130 | Acc: 0.8828 | Loss: 0.2012 | LR: 0.000809
# INFO:tensorflow:Step 4140 | Acc: 0.9453 | Loss: 0.1745 | LR: 0.000809
# INFO:tensorflow:Step 4150 | Acc: 0.8906 | Loss: 0.3132 | LR: 0.000808
# INFO:tensorflow:Step 4160 | Acc: 0.9297 | Loss: 0.1768 | LR: 0.000808
# INFO:tensorflow:Step 4170 | Acc: 0.8750 | Loss: 0.2273 | LR: 0.000807
# INFO:tensorflow:Step 4180 | Acc: 0.9141 | Loss: 0.2120 | LR: 0.000807
# INFO:tensorflow:Step 4190 | Acc: 0.8750 | Loss: 0.2360 | LR: 0.000807
# INFO:tensorflow:Step 4200 | Acc: 0.9062 | Loss: 0.2703 | LR: 0.000806
# INFO:tensorflow:Step 4210 | Acc: 0.9062 | Loss: 0.2366 | LR: 0.000806
# INFO:tensorflow:Step 4220 | Acc: 0.8984 | Loss: 0.2496 | LR: 0.000805
# INFO:tensorflow:Step 4230 | Acc: 0.8672 | Loss: 0.2818 | LR: 0.000805
# INFO:tensorflow:Step 4240 | Acc: 0.8672 | Loss: 0.2733 | LR: 0.000805
# INFO:tensorflow:Step 4250 | Acc: 0.9453 | Loss: 0.1466 | LR: 0.000804
# INFO:tensorflow:Step 4260 | Acc: 0.9141 | Loss: 0.2112 | LR: 0.000804
# INFO:tensorflow:Step 4270 | Acc: 0.9219 | Loss: 0.1987 | LR: 0.000803
# INFO:tensorflow:Step 4280 | Acc: 0.9297 | Loss: 0.2052 | LR: 0.000803
# INFO:tensorflow:Step 4290 | Acc: 0.8984 | Loss: 0.2817 | LR: 0.000802
# INFO:tensorflow:Step 4300 | Acc: 0.9062 | Loss: 0.2454 | LR: 0.000802
# INFO:tensorflow:Step 4310 | Acc: 0.8906 | Loss: 0.3042 | LR: 0.000802
# EPOCH 23
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 4320 | Acc: 0.8672 | Loss: 0.2873 | LR: 0.000801
# INFO:tensorflow:Step 4330 | Acc: 0.9219 | Loss: 0.2228 | LR: 0.000801
# INFO:tensorflow:Step 4340 | Acc: 0.8984 | Loss: 0.2331 | LR: 0.000800
# INFO:tensorflow:Step 4350 | Acc: 0.9141 | Loss: 0.2059 | LR: 0.000800
# INFO:tensorflow:Step 4360 | Acc: 0.8906 | Loss: 0.2391 | LR: 0.000800
# INFO:tensorflow:Step 4370 | Acc: 0.8672 | Loss: 0.2862 | LR: 0.000799
# INFO:tensorflow:Step 4380 | Acc: 0.9297 | Loss: 0.2158 | LR: 0.000799
# INFO:tensorflow:Step 4390 | Acc: 0.8906 | Loss: 0.2278 | LR: 0.000798
# INFO:tensorflow:Step 4400 | Acc: 0.9453 | Loss: 0.1526 | LR: 0.000798
# INFO:tensorflow:Step 4410 | Acc: 0.9297 | Loss: 0.1888 | LR: 0.000798
# INFO:tensorflow:Step 4420 | Acc: 0.9375 | Loss: 0.1548 | LR: 0.000797
# INFO:tensorflow:Step 4430 | Acc: 0.9297 | Loss: 0.2116 | LR: 0.000797
# INFO:tensorflow:Step 4440 | Acc: 0.9062 | Loss: 0.2803 | LR: 0.000796
# INFO:tensorflow:Step 4450 | Acc: 0.9297 | Loss: 0.1884 | LR: 0.000796
# INFO:tensorflow:Step 4460 | Acc: 0.8984 | Loss: 0.2575 | LR: 0.000796
# INFO:tensorflow:Step 4470 | Acc: 0.8750 | Loss: 0.2587 | LR: 0.000795
# INFO:tensorflow:Step 4480 | Acc: 0.8984 | Loss: 0.2325 | LR: 0.000795
# INFO:tensorflow:Step 4490 | Acc: 0.8906 | Loss: 0.2471 | LR: 0.000794
# INFO:tensorflow:Step 4500 | Acc: 0.9062 | Loss: 0.2231 | LR: 0.000794
# EPOCH 24
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 4510 | Acc: 0.8672 | Loss: 0.2607 | LR: 0.000793
# INFO:tensorflow:Step 4520 | Acc: 0.9297 | Loss: 0.1745 | LR: 0.000793
# INFO:tensorflow:Step 4530 | Acc: 0.9297 | Loss: 0.1600 | LR: 0.000793
# INFO:tensorflow:Step 4540 | Acc: 0.8750 | Loss: 0.2893 | LR: 0.000792
# INFO:tensorflow:Step 4550 | Acc: 0.9062 | Loss: 0.2279 | LR: 0.000792
# INFO:tensorflow:Step 4560 | Acc: 0.9219 | Loss: 0.2132 | LR: 0.000791
# INFO:tensorflow:Step 4570 | Acc: 0.8984 | Loss: 0.2634 | LR: 0.000791
# INFO:tensorflow:Step 4580 | Acc: 0.9141 | Loss: 0.2275 | LR: 0.000791
# INFO:tensorflow:Step 4590 | Acc: 0.8828 | Loss: 0.2732 | LR: 0.000790
# INFO:tensorflow:Step 4600 | Acc: 0.9141 | Loss: 0.2264 | LR: 0.000790
# INFO:tensorflow:Step 4610 | Acc: 0.9219 | Loss: 0.2204 | LR: 0.000789
# INFO:tensorflow:Step 4620 | Acc: 0.9062 | Loss: 0.2580 | LR: 0.000789
# INFO:tensorflow:Step 4630 | Acc: 0.9141 | Loss: 0.2356 | LR: 0.000789
# INFO:tensorflow:Step 4640 | Acc: 0.8516 | Loss: 0.3271 | LR: 0.000788
# INFO:tensorflow:Step 4650 | Acc: 0.8906 | Loss: 0.2092 | LR: 0.000788
# INFO:tensorflow:Step 4660 | Acc: 0.8594 | Loss: 0.2965 | LR: 0.000787
# INFO:tensorflow:Step 4670 | Acc: 0.9219 | Loss: 0.2023 | LR: 0.000787
# INFO:tensorflow:Step 4680 | Acc: 0.9375 | Loss: 0.1816 | LR: 0.000787
# INFO:tensorflow:Step 4690 | Acc: 0.9219 | Loss: 0.1836 | LR: 0.000786
# INFO:tensorflow:Step 4700 | Acc: 0.9219 | Loss: 0.2007 | LR: 0.000786
# EPOCH 25
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 4710 | Acc: 0.9219 | Loss: 0.1866 | LR: 0.000785
# INFO:tensorflow:Step 4720 | Acc: 0.8984 | Loss: 0.2592 | LR: 0.000785
# INFO:tensorflow:Step 4730 | Acc: 0.9453 | Loss: 0.1512 | LR: 0.000785
# INFO:tensorflow:Step 4740 | Acc: 0.8828 | Loss: 0.2316 | LR: 0.000784
# INFO:tensorflow:Step 4750 | Acc: 0.9141 | Loss: 0.2281 | LR: 0.000784
# INFO:tensorflow:Step 4760 | Acc: 0.9531 | Loss: 0.1325 | LR: 0.000783
# INFO:tensorflow:Step 4770 | Acc: 0.8750 | Loss: 0.2708 | LR: 0.000783
# INFO:tensorflow:Step 4780 | Acc: 0.9531 | Loss: 0.1671 | LR: 0.000783
# INFO:tensorflow:Step 4790 | Acc: 0.8984 | Loss: 0.2358 | LR: 0.000782
# INFO:tensorflow:Step 4800 | Acc: 0.8906 | Loss: 0.2754 | LR: 0.000782
# INFO:tensorflow:Step 4810 | Acc: 0.8828 | Loss: 0.2808 | LR: 0.000781
# INFO:tensorflow:Step 4820 | Acc: 0.9141 | Loss: 0.2159 | LR: 0.000781
# INFO:tensorflow:Step 4830 | Acc: 0.9062 | Loss: 0.2135 | LR: 0.000781
# INFO:tensorflow:Step 4840 | Acc: 0.9219 | Loss: 0.1689 | LR: 0.000780
# INFO:tensorflow:Step 4850 | Acc: 0.9219 | Loss: 0.1434 | LR: 0.000780
# INFO:tensorflow:Step 4860 | Acc: 0.8984 | Loss: 0.2484 | LR: 0.000779
# INFO:tensorflow:Step 4870 | Acc: 0.8828 | Loss: 0.2416 | LR: 0.000779
# INFO:tensorflow:Step 4880 | Acc: 0.8828 | Loss: 0.2499 | LR: 0.000779
# INFO:tensorflow:Step 4890 | Acc: 0.8438 | Loss: 0.2682 | LR: 0.000778
# EPOCH 26
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 4900 | Acc: 0.9062 | Loss: 0.1740 | LR: 0.000778
# INFO:tensorflow:Step 4910 | Acc: 0.9297 | Loss: 0.2339 | LR: 0.000777
# INFO:tensorflow:Step 4920 | Acc: 0.9297 | Loss: 0.1820 | LR: 0.000777
# INFO:tensorflow:Step 4930 | Acc: 0.8750 | Loss: 0.2414 | LR: 0.000777
# INFO:tensorflow:Step 4940 | Acc: 0.9141 | Loss: 0.1780 | LR: 0.000776
# INFO:tensorflow:Step 4950 | Acc: 0.9141 | Loss: 0.1965 | LR: 0.000776
# INFO:tensorflow:Step 4960 | Acc: 0.8828 | Loss: 0.2694 | LR: 0.000775
# INFO:tensorflow:Step 4970 | Acc: 0.9141 | Loss: 0.2052 | LR: 0.000775
# INFO:tensorflow:Step 4980 | Acc: 0.9297 | Loss: 0.2168 | LR: 0.000775
# INFO:tensorflow:Step 4990 | Acc: 0.8906 | Loss: 0.2731 | LR: 0.000774
# INFO:tensorflow:Step 5000 | Acc: 0.9062 | Loss: 0.2379 | LR: 0.000774
# INFO:tensorflow:Step 5010 | Acc: 0.9219 | Loss: 0.2232 | LR: 0.000773
# INFO:tensorflow:Step 5020 | Acc: 0.9297 | Loss: 0.1908 | LR: 0.000773
# INFO:tensorflow:Step 5030 | Acc: 0.9453 | Loss: 0.1444 | LR: 0.000773
# INFO:tensorflow:Step 5040 | Acc: 0.9141 | Loss: 0.2379 | LR: 0.000772
# INFO:tensorflow:Step 5050 | Acc: 0.8984 | Loss: 0.2456 | LR: 0.000772
# INFO:tensorflow:Step 5060 | Acc: 0.9531 | Loss: 0.1672 | LR: 0.000771
# INFO:tensorflow:Step 5070 | Acc: 0.9141 | Loss: 0.2229 | LR: 0.000771
# INFO:tensorflow:Step 5080 | Acc: 0.8906 | Loss: 0.1899 | LR: 0.000771
# INFO:tensorflow:Step 5090 | Acc: 0.8984 | Loss: 0.2274 | LR: 0.000770
# EPOCH 27
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 5100 | Acc: 0.9219 | Loss: 0.2391 | LR: 0.000770
# INFO:tensorflow:Step 5110 | Acc: 0.9297 | Loss: 0.1827 | LR: 0.000769
# INFO:tensorflow:Step 5120 | Acc: 0.9609 | Loss: 0.1160 | LR: 0.000769
# INFO:tensorflow:Step 5130 | Acc: 0.9375 | Loss: 0.1936 | LR: 0.000769
# INFO:tensorflow:Step 5140 | Acc: 0.9141 | Loss: 0.2169 | LR: 0.000768
# INFO:tensorflow:Step 5150 | Acc: 0.8594 | Loss: 0.2372 | LR: 0.000768
# INFO:tensorflow:Step 5160 | Acc: 0.9062 | Loss: 0.2107 | LR: 0.000767
# INFO:tensorflow:Step 5170 | Acc: 0.9141 | Loss: 0.2164 | LR: 0.000767
# INFO:tensorflow:Step 5180 | Acc: 0.9062 | Loss: 0.1947 | LR: 0.000767
# INFO:tensorflow:Step 5190 | Acc: 0.9453 | Loss: 0.1479 | LR: 0.000766
# INFO:tensorflow:Step 5200 | Acc: 0.8984 | Loss: 0.2267 | LR: 0.000766
# INFO:tensorflow:Step 5210 | Acc: 0.9531 | Loss: 0.1641 | LR: 0.000765
# INFO:tensorflow:Step 5220 | Acc: 0.8906 | Loss: 0.1840 | LR: 0.000765
# INFO:tensorflow:Step 5230 | Acc: 0.9297 | Loss: 0.1896 | LR: 0.000765
# INFO:tensorflow:Step 5240 | Acc: 0.8750 | Loss: 0.2874 | LR: 0.000764
# INFO:tensorflow:Step 5250 | Acc: 0.8906 | Loss: 0.2833 | LR: 0.000764
# INFO:tensorflow:Step 5260 | Acc: 0.8984 | Loss: 0.2694 | LR: 0.000764
# INFO:tensorflow:Step 5270 | Acc: 0.9219 | Loss: 0.2194 | LR: 0.000763
# INFO:tensorflow:Step 5280 | Acc: 0.9141 | Loss: 0.2319 | LR: 0.000763
# INFO:tensorflow:Step 5290 | Acc: 0.8906 | Loss: 0.2312 | LR: 0.000762
# EPOCH 28
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 5300 | Acc: 0.9297 | Loss: 0.1386 | LR: 0.000762
# INFO:tensorflow:Step 5310 | Acc: 0.8906 | Loss: 0.2276 | LR: 0.000762
# INFO:tensorflow:Step 5320 | Acc: 0.9375 | Loss: 0.1411 | LR: 0.000761
# INFO:tensorflow:Step 5330 | Acc: 0.9219 | Loss: 0.1869 | LR: 0.000761
# INFO:tensorflow:Step 5340 | Acc: 0.9375 | Loss: 0.1630 | LR: 0.000760
# INFO:tensorflow:Step 5350 | Acc: 0.9375 | Loss: 0.2034 | LR: 0.000760
# INFO:tensorflow:Step 5360 | Acc: 0.9141 | Loss: 0.1866 | LR: 0.000760
# INFO:tensorflow:Step 5370 | Acc: 0.9219 | Loss: 0.2451 | LR: 0.000759
# INFO:tensorflow:Step 5380 | Acc: 0.9219 | Loss: 0.1926 | LR: 0.000759
# INFO:tensorflow:Step 5390 | Acc: 0.9297 | Loss: 0.1426 | LR: 0.000758
# INFO:tensorflow:Step 5400 | Acc: 0.9453 | Loss: 0.1517 | LR: 0.000758
# INFO:tensorflow:Step 5410 | Acc: 0.9297 | Loss: 0.1959 | LR: 0.000758
# INFO:tensorflow:Step 5420 | Acc: 0.8984 | Loss: 0.2375 | LR: 0.000757
# INFO:tensorflow:Step 5430 | Acc: 0.9297 | Loss: 0.1750 | LR: 0.000757
# INFO:tensorflow:Step 5440 | Acc: 0.9375 | Loss: 0.1760 | LR: 0.000757
# INFO:tensorflow:Step 5450 | Acc: 0.8750 | Loss: 0.2547 | LR: 0.000756
# INFO:tensorflow:Step 5460 | Acc: 0.8984 | Loss: 0.2296 | LR: 0.000756
# INFO:tensorflow:Step 5470 | Acc: 0.9219 | Loss: 0.1749 | LR: 0.000755
# INFO:tensorflow:Step 5480 | Acc: 0.9141 | Loss: 0.2699 | LR: 0.000755
# EPOCH 29
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 5490 | Acc: 0.9219 | Loss: 0.1785 | LR: 0.000755
# INFO:tensorflow:Step 5500 | Acc: 0.9297 | Loss: 0.2178 | LR: 0.000754
# INFO:tensorflow:Step 5510 | Acc: 0.8906 | Loss: 0.2036 | LR: 0.000754
# INFO:tensorflow:Step 5520 | Acc: 0.8828 | Loss: 0.2627 | LR: 0.000753
# INFO:tensorflow:Step 5530 | Acc: 0.9297 | Loss: 0.1379 | LR: 0.000753
# INFO:tensorflow:Step 5540 | Acc: 0.9609 | Loss: 0.1380 | LR: 0.000753
# INFO:tensorflow:Step 5550 | Acc: 0.9297 | Loss: 0.2237 | LR: 0.000752
# INFO:tensorflow:Step 5560 | Acc: 0.9375 | Loss: 0.1641 | LR: 0.000752
# INFO:tensorflow:Step 5570 | Acc: 0.9297 | Loss: 0.1695 | LR: 0.000751
# INFO:tensorflow:Step 5580 | Acc: 0.8906 | Loss: 0.2268 | LR: 0.000751
# INFO:tensorflow:Step 5590 | Acc: 0.9219 | Loss: 0.2150 | LR: 0.000751
# INFO:tensorflow:Step 5600 | Acc: 0.9609 | Loss: 0.1435 | LR: 0.000750
# INFO:tensorflow:Step 5610 | Acc: 0.9141 | Loss: 0.2167 | LR: 0.000750
# INFO:tensorflow:Step 5620 | Acc: 0.9062 | Loss: 0.2519 | LR: 0.000750
# INFO:tensorflow:Step 5630 | Acc: 0.9375 | Loss: 0.2005 | LR: 0.000749
# INFO:tensorflow:Step 5640 | Acc: 0.9531 | Loss: 0.1655 | LR: 0.000749
# INFO:tensorflow:Step 5650 | Acc: 0.8516 | Loss: 0.3377 | LR: 0.000748
# INFO:tensorflow:Step 5660 | Acc: 0.9297 | Loss: 0.1528 | LR: 0.000748
# INFO:tensorflow:Step 5670 | Acc: 0.9375 | Loss: 0.1518 | LR: 0.000748
# INFO:tensorflow:Step 5680 | Acc: 0.9375 | Loss: 0.1525 | LR: 0.000747
# EPOCH 30
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 5690 | Acc: 0.9531 | Loss: 0.1630 | LR: 0.000747
# INFO:tensorflow:Step 5700 | Acc: 0.8906 | Loss: 0.2424 | LR: 0.000746
# INFO:tensorflow:Step 5710 | Acc: 0.9219 | Loss: 0.1633 | LR: 0.000746
# INFO:tensorflow:Step 5720 | Acc: 0.9531 | Loss: 0.1219 | LR: 0.000746
# INFO:tensorflow:Step 5730 | Acc: 0.9062 | Loss: 0.1785 | LR: 0.000745
# INFO:tensorflow:Step 5740 | Acc: 0.8906 | Loss: 0.2423 | LR: 0.000745
# INFO:tensorflow:Step 5750 | Acc: 0.8984 | Loss: 0.2099 | LR: 0.000745
# INFO:tensorflow:Step 5760 | Acc: 0.9375 | Loss: 0.1537 | LR: 0.000744
# INFO:tensorflow:Step 5770 | Acc: 0.9531 | Loss: 0.1337 | LR: 0.000744
# INFO:tensorflow:Step 5780 | Acc: 0.9297 | Loss: 0.1649 | LR: 0.000743
# INFO:tensorflow:Step 5790 | Acc: 0.9141 | Loss: 0.1669 | LR: 0.000743
# INFO:tensorflow:Step 5800 | Acc: 0.9297 | Loss: 0.1333 | LR: 0.000743
# INFO:tensorflow:Step 5810 | Acc: 0.9141 | Loss: 0.2042 | LR: 0.000742
# INFO:tensorflow:Step 5820 | Acc: 0.9609 | Loss: 0.1415 | LR: 0.000742
# INFO:tensorflow:Step 5830 | Acc: 0.9531 | Loss: 0.1161 | LR: 0.000742
# INFO:tensorflow:Step 5840 | Acc: 0.9062 | Loss: 0.2299 | LR: 0.000741
# INFO:tensorflow:Step 5850 | Acc: 0.9609 | Loss: 0.1264 | LR: 0.000741
# INFO:tensorflow:Step 5860 | Acc: 0.9609 | Loss: 0.1157 | LR: 0.000740
# INFO:tensorflow:Step 5870 | Acc: 0.8984 | Loss: 0.1704 | LR: 0.000740
# EPOCH 31
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 5880 | Acc: 0.9453 | Loss: 0.1700 | LR: 0.000740
# INFO:tensorflow:Step 5890 | Acc: 0.9141 | Loss: 0.1913 | LR: 0.000739
# INFO:tensorflow:Step 5900 | Acc: 0.9062 | Loss: 0.2248 | LR: 0.000739
# INFO:tensorflow:Step 5910 | Acc: 0.9141 | Loss: 0.1801 | LR: 0.000738
# INFO:tensorflow:Step 5920 | Acc: 0.9297 | Loss: 0.1530 | LR: 0.000738
# INFO:tensorflow:Step 5930 | Acc: 0.8906 | Loss: 0.2226 | LR: 0.000738
# INFO:tensorflow:Step 5940 | Acc: 0.9297 | Loss: 0.1849 | LR: 0.000737
# INFO:tensorflow:Step 5950 | Acc: 0.9297 | Loss: 0.1559 | LR: 0.000737
# INFO:tensorflow:Step 5960 | Acc: 0.9531 | Loss: 0.1376 | LR: 0.000737
# INFO:tensorflow:Step 5970 | Acc: 0.9219 | Loss: 0.1758 | LR: 0.000736
# INFO:tensorflow:Step 5980 | Acc: 0.9141 | Loss: 0.1608 | LR: 0.000736
# INFO:tensorflow:Step 5990 | Acc: 0.9453 | Loss: 0.1523 | LR: 0.000735
# INFO:tensorflow:Step 6000 | Acc: 0.9531 | Loss: 0.1240 | LR: 0.000735
# INFO:tensorflow:Step 6010 | Acc: 0.9219 | Loss: 0.1639 | LR: 0.000735
# INFO:tensorflow:Step 6020 | Acc: 0.9141 | Loss: 0.1679 | LR: 0.000734
# INFO:tensorflow:Step 6030 | Acc: 0.9062 | Loss: 0.2289 | LR: 0.000734
# INFO:tensorflow:Step 6040 | Acc: 0.9375 | Loss: 0.1752 | LR: 0.000734
# INFO:tensorflow:Step 6050 | Acc: 0.9609 | Loss: 0.1433 | LR: 0.000733
# INFO:tensorflow:Step 6060 | Acc: 0.9375 | Loss: 0.1556 | LR: 0.000733
# INFO:tensorflow:Step 6070 | Acc: 0.8828 | Loss: 0.2509 | LR: 0.000732
# EPOCH 32
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 6080 | Acc: 0.9297 | Loss: 0.1492 | LR: 0.000732
# INFO:tensorflow:Step 6090 | Acc: 0.9453 | Loss: 0.1251 | LR: 0.000732
# INFO:tensorflow:Step 6100 | Acc: 0.9531 | Loss: 0.1492 | LR: 0.000731
# INFO:tensorflow:Step 6110 | Acc: 0.9844 | Loss: 0.0972 | LR: 0.000731
# INFO:tensorflow:Step 6120 | Acc: 0.9297 | Loss: 0.2150 | LR: 0.000731
# INFO:tensorflow:Step 6130 | Acc: 0.9219 | Loss: 0.1786 | LR: 0.000730
# INFO:tensorflow:Step 6140 | Acc: 0.9688 | Loss: 0.0930 | LR: 0.000730
# INFO:tensorflow:Step 6150 | Acc: 0.9375 | Loss: 0.1302 | LR: 0.000729
# INFO:tensorflow:Step 6160 | Acc: 0.8984 | Loss: 0.2364 | LR: 0.000729
# INFO:tensorflow:Step 6170 | Acc: 0.9609 | Loss: 0.1210 | LR: 0.000729
# INFO:tensorflow:Step 6180 | Acc: 0.9766 | Loss: 0.0989 | LR: 0.000728
# INFO:tensorflow:Step 6190 | Acc: 0.9219 | Loss: 0.2344 | LR: 0.000728
# INFO:tensorflow:Step 6200 | Acc: 0.9219 | Loss: 0.2087 | LR: 0.000728
# INFO:tensorflow:Step 6210 | Acc: 0.8750 | Loss: 0.2040 | LR: 0.000727
# INFO:tensorflow:Step 6220 | Acc: 0.8828 | Loss: 0.2396 | LR: 0.000727
# INFO:tensorflow:Step 6230 | Acc: 0.9062 | Loss: 0.2838 | LR: 0.000726
# INFO:tensorflow:Step 6240 | Acc: 0.9375 | Loss: 0.1702 | LR: 0.000726
# INFO:tensorflow:Step 6250 | Acc: 0.9375 | Loss: 0.1642 | LR: 0.000726
# INFO:tensorflow:Step 6260 | Acc: 0.9219 | Loss: 0.1745 | LR: 0.000725
# INFO:tensorflow:Step 6270 | Acc: 0.9219 | Loss: 0.1742 | LR: 0.000725
# EPOCH 33
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 6280 | Acc: 0.9297 | Loss: 0.1664 | LR: 0.000725
# INFO:tensorflow:Step 6290 | Acc: 0.9453 | Loss: 0.2162 | LR: 0.000724
# INFO:tensorflow:Step 6300 | Acc: 0.8906 | Loss: 0.1897 | LR: 0.000724
# INFO:tensorflow:Step 6310 | Acc: 0.9297 | Loss: 0.1623 | LR: 0.000723
# INFO:tensorflow:Step 6320 | Acc: 0.9062 | Loss: 0.2271 | LR: 0.000723
# INFO:tensorflow:Step 6330 | Acc: 0.9297 | Loss: 0.2564 | LR: 0.000723
# INFO:tensorflow:Step 6340 | Acc: 0.9375 | Loss: 0.2458 | LR: 0.000722
# INFO:tensorflow:Step 6350 | Acc: 0.9297 | Loss: 0.1573 | LR: 0.000722
# INFO:tensorflow:Step 6360 | Acc: 0.9688 | Loss: 0.0820 | LR: 0.000722
# INFO:tensorflow:Step 6370 | Acc: 0.9297 | Loss: 0.1660 | LR: 0.000721
# INFO:tensorflow:Step 6380 | Acc: 0.8750 | Loss: 0.2103 | LR: 0.000721
# INFO:tensorflow:Step 6390 | Acc: 0.9297 | Loss: 0.2164 | LR: 0.000721
# INFO:tensorflow:Step 6400 | Acc: 0.9297 | Loss: 0.1531 | LR: 0.000720
# INFO:tensorflow:Step 6410 | Acc: 0.8906 | Loss: 0.2522 | LR: 0.000720
# INFO:tensorflow:Step 6420 | Acc: 0.9141 | Loss: 0.2013 | LR: 0.000719
# INFO:tensorflow:Step 6430 | Acc: 0.9453 | Loss: 0.1399 | LR: 0.000719
# INFO:tensorflow:Step 6440 | Acc: 0.9219 | Loss: 0.1754 | LR: 0.000719
# INFO:tensorflow:Step 6450 | Acc: 0.9375 | Loss: 0.1274 | LR: 0.000718
# INFO:tensorflow:Step 6460 | Acc: 0.9453 | Loss: 0.1757 | LR: 0.000718
# EPOCH 34
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 6470 | Acc: 0.9453 | Loss: 0.1261 | LR: 0.000718
# INFO:tensorflow:Step 6480 | Acc: 0.9219 | Loss: 0.1835 | LR: 0.000717
# INFO:tensorflow:Step 6490 | Acc: 0.9375 | Loss: 0.1599 | LR: 0.000717
# INFO:tensorflow:Step 6500 | Acc: 0.9297 | Loss: 0.1733 | LR: 0.000716
# INFO:tensorflow:Step 6510 | Acc: 0.8984 | Loss: 0.2350 | LR: 0.000716
# INFO:tensorflow:Step 6520 | Acc: 0.9531 | Loss: 0.1396 | LR: 0.000716
# INFO:tensorflow:Step 6530 | Acc: 0.9531 | Loss: 0.2096 | LR: 0.000715
# INFO:tensorflow:Step 6540 | Acc: 0.8828 | Loss: 0.2626 | LR: 0.000715
# INFO:tensorflow:Step 6550 | Acc: 0.9375 | Loss: 0.1140 | LR: 0.000715
# INFO:tensorflow:Step 6560 | Acc: 0.9219 | Loss: 0.2346 | LR: 0.000714
# INFO:tensorflow:Step 6570 | Acc: 0.9609 | Loss: 0.1270 | LR: 0.000714
# INFO:tensorflow:Step 6580 | Acc: 0.9062 | Loss: 0.2129 | LR: 0.000714
# INFO:tensorflow:Step 6590 | Acc: 0.9531 | Loss: 0.1443 | LR: 0.000713
# INFO:tensorflow:Step 6600 | Acc: 0.9141 | Loss: 0.2304 | LR: 0.000713
# INFO:tensorflow:Step 6610 | Acc: 0.9297 | Loss: 0.1594 | LR: 0.000712
# INFO:tensorflow:Step 6620 | Acc: 0.9219 | Loss: 0.1419 | LR: 0.000712
# INFO:tensorflow:Step 6630 | Acc: 0.9219 | Loss: 0.1933 | LR: 0.000712
# INFO:tensorflow:Step 6640 | Acc: 0.9375 | Loss: 0.2598 | LR: 0.000711
# INFO:tensorflow:Step 6650 | Acc: 0.9375 | Loss: 0.1944 | LR: 0.000711
# INFO:tensorflow:Step 6660 | Acc: 0.9688 | Loss: 0.1464 | LR: 0.000711
# EPOCH 35
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/train.txt
# INFO:tensorflow:Step 6670 | Acc: 0.9531 | Loss: 0.1126 | LR: 0.000710
# INFO:tensorflow:Step 6680 | Acc: 0.9453 | Loss: 0.1971 | LR: 0.000710
# INFO:tensorflow:Step 6690 | Acc: 0.9453 | Loss: 0.1162 | LR: 0.000710
# INFO:tensorflow:Step 6700 | Acc: 0.9141 | Loss: 0.2141 | LR: 0.000709
# INFO:tensorflow:Step 6710 | Acc: 0.8828 | Loss: 0.2674 | LR: 0.000709
# INFO:tensorflow:Step 6720 | Acc: 0.9531 | Loss: 0.1155 | LR: 0.000708
# INFO:tensorflow:Step 6730 | Acc: 0.9297 | Loss: 0.1818 | LR: 0.000708
# INFO:tensorflow:Step 6740 | Acc: 0.9531 | Loss: 0.1259 | LR: 0.000708
# INFO:tensorflow:Step 6750 | Acc: 0.9062 | Loss: 0.1913 | LR: 0.000707
# INFO:tensorflow:Step 6760 | Acc: 0.9453 | Loss: 0.1107 | LR: 0.000707
# INFO:tensorflow:Step 6770 | Acc: 0.9219 | Loss: 0.2129 | LR: 0.000707
# INFO:tensorflow:Step 6780 | Acc: 0.8828 | Loss: 0.2454 | LR: 0.000706
# INFO:tensorflow:Step 6790 | Acc: 0.9297 | Loss: 0.1596 | LR: 0.000706
# INFO:tensorflow:Step 6800 | Acc: 0.9219 | Loss: 0.1709 | LR: 0.000706
# INFO:tensorflow:Step 6810 | Acc: 0.8984 | Loss: 0.1599 | LR: 0.000705
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f8d453d7830>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-4d48404a40a2> in <module>()
#      21             loss = tf.reduce_mean(loss)
#      22         optimizer.lr.assign(decay_lr(global_step)) # assign new learning rate
# ---> 23         grads = tape.gradient(loss, model.trainable_variables) # compute gradient
#      24         grads, _ = tf.clip_by_global_norm(grads, parameters['clip_norm']) # clip gradient to avoid overfitting
#      25         optimizer.apply_gradients(zip(grads, model.trainable_variables)) # update weights
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1078         output_gradients=output_gradients,
#    1079         sources_raw=flat_sources_raw,
# -> 1080         unconnected_gradients=unconnected_gradients)
#    1081
#    1082     if not self._persistent:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     157       gradient_name_scope += forward_pass_name_scope + "/"
#     158     with ops.name_scope(gradient_name_scope):
# --> 159       return grad_fn(mock_op, *out_grads)
#     160   else:
#     161     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/cudnn_rnn_grad.py in _cudnn_rnn_backward(op, *grads)
#      45       rnn_mode=op.get_attr("rnn_mode"),
#      46       input_mode=op.get_attr("input_mode"),
# ---> 47       direction=op.get_attr("direction"))
#      48
#      49
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_cudnn_rnn_ops.py in cudnn_rnn_backprop(input, input_h, input_c, params, output, output_h, output_c, output_backprop, output_h_backprop, output_c_backprop, reserve_space, rnn_mode, input_mode, direction, dropout, seed, seed2, name)
#     270         output_c_backprop, reserve_space, "rnn_mode", rnn_mode, "input_mode",
#     271         input_mode, "direction", direction, "dropout", dropout, "seed", seed,
# --> 272         "seed2", seed2)
#     273       _result = _CudnnRNNBackpropOutput._make(_result)
#     274       return _result
#
# KeyboardInterrupt:

# %%
# testing
m = tf.keras.metrics.Accuracy()
for texts, labels in dataset(isTraining=False, parameters=parameters):
    logits = model(texts, training=False)
    y_pred = tf.argmax(logits, axis=-1)
    m.update_state(y_true=labels, y_pred=y_pred)
acc = m.result().numpy()
logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
# Out:
# Reading Data from  /content/drive/My Drive/Tensorflow Course/ch10-RNN-sentiment-analysis/data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.879

# %% [markdown]
# # Sentiment Analysis with CNN

# %% [markdown]
# import package

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Reshape, Embedding, Activation
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPool2D, Input, concatenate
from tensorflow.keras.preprocessing.sequence import pad_sequences
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# load in data

# %%
# hyper-parameters
vocab_size = 3000
max_seq_len = 300
embedding_dim = 100

# load-in dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)
# x_train = array of indices, you can see whats in it
print(x_train[1]) # [1, 194, 1153, 194, 2, 78, 228, 5, 6, 1463, 2, 2, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 2, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 2, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 2, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 2, 5, 163, 11, 2, 2, 4, 1153, 9, 194, 775, 7, 2, 2, 349, 2637, 148, 605, 2, 2, 15, 123, 125, 68, 2, 2, 15, 349, 165, 2, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 2, 228, 2, 5, 2, 656, 245, 2350, 5, 4, 2, 131, 152, 491, 18, 2, 32, 2, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]
print(x_train.shape) # (25000,)
print(y_train.shape) # (25000,)
print(x_test.shape)  # (25000,)
print(y_test.shape)  # (25000,)

# pad the sequence 
x_train = pad_sequences(x_train, maxlen = max_seq_len)
x_test = pad_sequences(x_test, maxlen = max_seq_len)
print(x_train.shape) # (25000, 300)
print(x_test.shape)  # (25000, 300)
# Out:
# [1, 194, 1153, 194, 2, 78, 228, 5, 6, 1463, 2, 2, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 2, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 2, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 2, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 2, 5, 163, 11, 2, 2, 4, 1153, 9, 194, 775, 7, 2, 2, 349, 2637, 148, 605, 2, 2, 15, 123, 125, 68, 2, 2, 15, 349, 165, 2, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 2, 228, 2, 5, 2, 656, 245, 2350, 5, 4, 2, 131, 152, 491, 18, 2, 32, 2, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]
# (25000,)
# (25000,)
# (25000,)
# (25000,)
# (25000, 300)
# (25000, 300)

# %% [markdown]
# Model Definition

# %%
# different size of kernal
filter_sizes = [3,4,5]

def convolutions(vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes):
    inputs = Input(shape = (max_seq_len, embedding_dimension, 1))
    cnns = []
    for size in filter_sizes:
        cnn = Conv2D(filters=64, kernel_size=(size, embedding_dimension), strides=1, padding='valid', activation='relu')(inputs)
        pooling = MaxPool2D(pool_size=(max_seq_len-size+1, 1), padding='valid')(cnn)
        cnns.append(pooling)
    cnns_outputs = concatenate(cnns)
    model = Model(inputs=inputs, outputs=cnns_outputs)
    return model

def cnn_nlp_model(vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes):
    model = Sequential([
        Embedding(input_dim=vocabulary_size, output_dim=embedding_dimension, input_length=max_seq_len),
        Reshape(target_shape=(max_seq_len, embedding_dimension, 1)), # 2D -> 3D
        convolutions(vocab_size, embedding_dim, max_seq_len, filter_sizes),
        Flatten(),
        Dense(10, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# Model Training

# %%
model = cnn_nlp_model(vocab_size, embedding_dim, max_seq_len, filter_sizes)
history = model.fit(x_train, y_train, batch_size=64, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 102s 320ms/step - loss: 0.5931 - accuracy: 0.6537 - val_loss: 0.3187 - val_accuracy: 0.8670
# Epoch 2/5
# 313/313 [==============================] - 100s 319ms/step - loss: 0.2874 - accuracy: 0.8814 - val_loss: 0.3001 - val_accuracy: 0.8750
# Epoch 3/5
# 313/313 [==============================] - 100s 319ms/step - loss: 0.1970 - accuracy: 0.9275 - val_loss: 0.2923 - val_accuracy: 0.8790
# Epoch 4/5
# 313/313 [==============================] - 100s 319ms/step - loss: 0.1394 - accuracy: 0.9506 - val_loss: 0.3239 - val_accuracy: 0.8808
# Epoch 5/5
# 313/313 [==============================] - 100s 319ms/step - loss: 0.0891 - accuracy: 0.9732 - val_loss: 0.3590 - val_accuracy: 0.8786

# %% [markdown]
# Second way to define model

# %%
# different size of kernal
filter_sizes = [3,4,5]

def convolutions(vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes):
    inputs = Input(shape = (max_seq_len, embedding_dimension, 1))
    cnns = []
    for size in filter_sizes:
        cnn = Conv2D(filters=64, kernel_size=(size, embedding_dimension), strides=1, padding='valid', activation='relu')(inputs)
        pooling = MaxPool2D(pool_size=(max_seq_len-size+1, 1), padding='valid')(cnn)
        cnns.append(pooling)
    cnns_outputs = concatenate(cnns)
    model = Model(inputs=inputs, outputs=cnns_outputs)
    return model

def cnn_nlp_model(vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes):
    model = Sequential()
    model.add(Embedding(input_dim=vocabulary_size, output_dim=embedding_dimension, input_length=max_seq_len))
    model.add(Reshape(target_shape=(max_seq_len, embedding_dimension, 1))) # 2D -> 3D
    model.add(convolutions(vocab_size, embedding_dim, max_seq_len, filter_sizes))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    return model

model = cnn_nlp_model(vocab_size, embedding_dim, max_seq_len, filter_sizes)
history = model.fit(x_train, y_train, batch_size=64, epochs=5, validation_split=0.2)

# %% [markdown]
# Third way to define model

# %%
class Model(tf.keras.Model):
    def __init__(self, vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes):
        super().__init__()
        self.embedding = Embedding(input_dim=vocabulary_size, output_dim=embedding_dimension, input_length=max_seq_len)
        self.reshape = Reshape(target_shape=(max_seq_len, embedding_dimension, 1)) # 2D -> 3D
        self.cnn1 = Conv2D(filters=64, kernel_size=(filter_sizes[0], embedding_dimension), strides=1, padding='valid', activation='relu')
        self.pool1 = MaxPool2D(pool_size=(max_seq_len-filter_sizes[0]+1, 1), padding='valid')
        self.cnn2 = Conv2D(filters=64, kernel_size=(filter_sizes[1], embedding_dimension), strides=1, padding='valid', activation='relu')
        self.pool2 = MaxPool2D(pool_size=(max_seq_len-filter_sizes[1]+1, 1), padding='valid')
        self.cnn3 = Conv2D(filters=64, kernel_size=(filter_sizes[2], embedding_dimension), strides=1, padding='valid', activation='relu')
        self.pool3 = MaxPool2D(pool_size=(max_seq_len-filter_sizes[2]+1, 1), padding='valid')
        self.flatten = Flatten()
        self.fc = Dense(10, activation='relu')
        self.dropout = Dropout(0.2)
        self.out_linear = Dense(1, activation='sigmoid')
  
    def call(self, inputs, training=False):
        x = self.embedding(inputs)
        x = self.reshape(x)
        x1 = self.cnn1(x)
        x1 = self.pool1(x1)
        x2 = self.cnn1(x)
        x2 = self.pool1(x2)
        x3 = self.cnn1(x)
        x3 = self.pool1(x3)
        x = concatenate([x1,x2,x3], axis=-1)
        x = self.flatten(x)
        x = self.fc(x)
        if training: x = self.dropout(x, training=training)
        x = self.out_linear(x)
        return x

model = Model(vocabulary_size=vocab_size, embedding_dimension=embedding_dim, max_seq_len=max_seq_len, filter_sizes=filter_sizes)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 114s 252ms/step - loss: 0.5067 - accuracy: 0.7373 - val_loss: 0.3429 - val_accuracy: 0.8514
# Epoch 2/5
# 313/313 [==============================] - 79s 251ms/step - loss: 0.2974 - accuracy: 0.8814 - val_loss: 0.2955 - val_accuracy: 0.8768
# Epoch 3/5
# 313/313 [==============================] - 79s 252ms/step - loss: 0.2126 - accuracy: 0.9245 - val_loss: 0.2936 - val_accuracy: 0.8812
# Epoch 4/5
# 313/313 [==============================] - 79s 251ms/step - loss: 0.1512 - accuracy: 0.9500 - val_loss: 0.3204 - val_accuracy: 0.8808
# Epoch 5/5
# 313/313 [==============================] - 79s 252ms/step - loss: 0.1009 - accuracy: 0.9701 - val_loss: 0.3583 - val_accuracy: 0.8762
